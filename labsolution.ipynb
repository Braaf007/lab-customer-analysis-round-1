# %% [markdown]
# Lab | Customer Analysis Round 1
# Remember the process:
# Case Study
# Get data
# Cleaning/Wrangling/EDA
# Processing Data
# Modeling
# Validation
# Reporting
# Abstract
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 csv files that are provided in the files_for_lab folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.

# %% [markdown]
# Read the three files into python as dataframes

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('files_for_lab/csv_files/file1.csv')

# %%
df2 = pd.read_csv('files_for_lab/csv_files/file2.csv')

# %%
df3 = pd.read_csv('files_for_lab/csv_files/file3.csv')

# %% [markdown]
# Show the DataFrame's shape.

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          Policy Type  Total Claim Amount  Vehicle Class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %% [markdown]
# Standardize header names.

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
cols = []

for i in range(len(df1.columns)):
    cols.append(df1.columns[i].lower())
    
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
cols = []

for i in range(len(df2.columns)):
    cols.append(df1.columns[i].lower())
    
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
cols = []

for i in range(len(df3.columns)):
    cols.append(df1.columns[i].lower())
    
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
df1.columns = cols
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
df2.columns = cols
df2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  policy type  \
# 0                      88                    1/0/00   633.600000
# 1                     114                    1/0/00   547.200000
# 2                     112                    1/0/00   537.600000
# 3                     214                    1/1/00  1027.200000
# 4                      94                    1/0/00   451.200000
# ..                    ...                       ...          ...
# 991                    70                    1/0/00   185.667213
# 992                    68                    1/0/00   140.747286
# 993                    70                    1/0/00   471.050488
# 994                    96                    1/0/00    28.460568
# 995                   111                    1/0/00   700.349052
#
#       vehicle class total claim amount
# 0     Personal Auto      Four-Door Car
# 1      Special Auto                SUV
# 2     Personal Auto       Two-Door Car
# 3     Personal Auto         Luxury Car
# 4    Corporate Auto       Two-Door Car
# ..              ...                ...
# 991   Personal Auto      Four-Door Car
# 992  Corporate Auto      Four-Door Car
# 993  Corporate Auto       Two-Door Car
# 994   Personal Auto       Two-Door Car
# 995   Personal Auto                SUV
#
# [996 rows x 11 columns]

# %%
df3.columns = cols
df3
# Out:
#      customer          st        gender             education  \
# 0     SA25987  Washington   3479.137523  High School or Below
# 1     TB86706     Arizona   2502.637401                Master
# 2     ZL73902      Nevada   3265.156348              Bachelor
# 3     KX23516  California   4455.843406  High School or Below
# 4     FN77294  California   7704.958480  High School or Below
# ...       ...         ...           ...                   ...
# 7065  LA72316  California  23405.987980              Bachelor
# 7066  PK87824  California   3096.511217               College
# 7067  TD14365  California   8163.890428              Bachelor
# 7068  UP19263  California   7524.442436               College
# 7069  Y167826  California   2611.836866               College
#
#      customer lifetime value  income  monthly premium auto  \
# 0                          M       0                   104
# 1                          M       0                    66
# 2                          F   25820                    82
# 3                          F       0                   121
# 4                          M   30366                   101
# ...                      ...     ...                   ...
# 7065                       M   71941                    73
# 7066                       F   21604                    79
# 7067                       M       0                    85
# 7068                       M   21941                    96
# 7069                       M       0                    77
#
#       number of open complaints     policy type  vehicle class  \
# 0                             0   Personal Auto     499.200000
# 1                             0   Personal Auto       3.468912
# 2                             0   Personal Auto     393.600000
# 3                             0   Personal Auto     699.615192
# 4                             2   Personal Auto     484.800000
# ...                         ...             ...            ...
# 7065                          0   Personal Auto     198.234764
# 7066                          0  Corporate Auto     379.200000
# 7067                          3  Corporate Auto     790.784983
# 7068                          0   Personal Auto     691.200000
# 7069                          0  Corporate Auto     369.600000
#
#      total claim amount
# 0          Two-Door Car
# 1          Two-Door Car
# 2         Four-Door Car
# 3                   SUV
# 4                   SUV
# ...                 ...
# 7065      Four-Door Car
# 7066      Four-Door Car
# 7067      Four-Door Car
# 7068      Four-Door Car
# 7069       Two-Door Car
#
# [7070 rows x 11 columns]

# %% [markdown]
# Concatenate the three dataframes

# %%
data = pd.concat([df1, df2, df3])
data
# Out:
#      customer          st   gender             education  \
# 0     RB50392  Washington      NaN                Master
# 1     QZ44356     Arizona        F              Bachelor
# 2     AI49188      Nevada        F              Bachelor
# 3     WW63253  California        M              Bachelor
# 4     GA49547  Washington        M  High School or Below
# ...       ...         ...      ...                   ...
# 7065  LA72316  California    23406              Bachelor
# 7066  PK87824  California  3096.51               College
# 7067  TD14365  California  8163.89              Bachelor
# 7068  UP19263  California  7524.44               College
# 7069  Y167826  California  2611.84               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                       M  71941.0                  73.0
# 7066                       F  21604.0                  79.0
# 7067                       M      0.0                  85.0
# 7068                       M  21941.0                  96.0
# 7069                       M      0.0                  77.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto        198.235
# 7066                         0  Corporate Auto          379.2
# 7067                         3  Corporate Auto        790.785
# 7068                         0   Personal Auto          691.2
# 7069                         0  Corporate Auto          369.6
#
#      total claim amount
# 0               2.70493
# 1               1131.46
# 2               566.472
# 3               529.881
# 4               17.2693
# ...                 ...
# 7065      Four-Door Car
# 7066      Four-Door Car
# 7067      Four-Door Car
# 7068      Four-Door Car
# 7069       Two-Door Car
#
# [12074 rows x 11 columns]

# %% [markdown]
# Which columns are numerical?
#
# Which columns are categorical?

# %%
df1.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
df2.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                         int64
# monthly premium auto           int64
# number of open complaints     object
# policy type                  float64
# vehicle class                 object
# total claim amount            object
# dtype: object

# %%
df3.dtypes
# Out:
# customer                      object
# st                            object
# gender                       float64
# education                     object
# customer lifetime value       object
# income                         int64
# monthly premium auto           int64
# number of open complaints      int64
# policy type                   object
# vehicle class                float64
# total claim amount            object
# dtype: object

# %%
df1.select_dtypes(include=np.number)
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 4003      NaN                   NaN                 NaN
# 4004      NaN                   NaN                 NaN
# 4005      NaN                   NaN                 NaN
# 4006      NaN                   NaN                 NaN
# 4007      NaN                   NaN                 NaN
#
# [4008 rows x 3 columns]

# %%
df2.select_dtypes(include=np.number)
# Out:
#      income  monthly premium auto  policy type
# 0     16061                    88   633.600000
# 1     79487                   114   547.200000
# 2     54230                   112   537.600000
# 3     71210                   214  1027.200000
# 4     94903                    94   451.200000
# ..      ...                   ...          ...
# 991   63513                    70   185.667213
# 992   58161                    68   140.747286
# 993   83640                    70   471.050488
# 994       0                    96    28.460568
# 995       0                   111   700.349052
#
# [996 rows x 3 columns]

# %%
df3.select_dtypes(include=np.number)
# Out:
#             gender  income  monthly premium auto  number of open complaints  \
# 0      3479.137523       0                   104                          0
# 1      2502.637401       0                    66                          0
# 2      3265.156348   25820                    82                          0
# 3      4455.843406       0                   121                          0
# 4      7704.958480   30366                   101                          2
# ...            ...     ...                   ...                        ...
# 7065  23405.987980   71941                    73                          0
# 7066   3096.511217   21604                    79                          0
# 7067   8163.890428       0                    85                          3
# 7068   7524.442436   21941                    96                          0
# 7069   2611.836866       0                    77                          0
#
#       vehicle class
# 0        499.200000
# 1          3.468912
# 2        393.600000
# 3        699.615192
# 4        484.800000
# ...             ...
# 7065     198.234764
# 7066     379.200000
# 7067     790.784983
# 7068     691.200000
# 7069     369.600000
#
# [7070 rows x 5 columns]

# %%
df1.select_dtypes(include=object)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value number of open complaints     policy type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# 3                 764586.18%                    1/0/00  Corporate Auto
# 4                 536307.65%                    1/0/00   Personal Auto
# ...                      ...                       ...             ...
# 4003                     NaN                       NaN             NaN
# 4004                     NaN                       NaN             NaN
# 4005                     NaN                       NaN             NaN
# 4006                     NaN                       NaN             NaN
# 4007                     NaN                       NaN             NaN
#
#       vehicle class
# 0     Four-Door Car
# 1     Four-Door Car
# 2      Two-Door Car
# 3               SUV
# 4     Four-Door Car
# ...             ...
# 4003            NaN
# 4004            NaN
# 4005            NaN
# 4006            NaN
# 4007            NaN
#
# [4008 rows x 8 columns]

# %%
df2.select_dtypes(include=object)
# Out:
#     customer          st gender education customer lifetime value  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%
# 1    CW49887  California      F    Master              462680.11%
# 2    MY31220  California      F   College              899704.02%
# 3    UH35128      Oregon      F   College             2580706.30%
# 4    WH52799     Arizona      F   College              380812.21%
# ..       ...         ...    ...       ...                     ...
# 991  HV85198     Arizona      M    Master              847141.75%
# 992  BS91566     Arizona      F   College              543121.91%
# 993  IL40123      Nevada      F   College              568964.41%
# 994  MY32149  California      F    Master              368672.38%
# 995  SA91515  California      M  Bachelor              399258.39%
#
#     number of open complaints   vehicle class total claim amount
# 0                      1/0/00   Personal Auto      Four-Door Car
# 1                      1/0/00    Special Auto                SUV
# 2                      1/0/00   Personal Auto       Two-Door Car
# 3                      1/1/00   Personal Auto         Luxury Car
# 4                      1/0/00  Corporate Auto       Two-Door Car
# ..                        ...             ...                ...
# 991                    1/0/00   Personal Auto      Four-Door Car
# 992                    1/0/00  Corporate Auto      Four-Door Car
# 993                    1/0/00  Corporate Auto       Two-Door Car
# 994                    1/0/00   Personal Auto       Two-Door Car
# 995                    1/0/00   Personal Auto                SUV
#
# [996 rows x 8 columns]

# %%
df3.select_dtypes(include=object)
# Out:
#      customer          st             education customer lifetime value  \
# 0     SA25987  Washington  High School or Below                       M
# 1     TB86706     Arizona                Master                       M
# 2     ZL73902      Nevada              Bachelor                       F
# 3     KX23516  California  High School or Below                       F
# 4     FN77294  California  High School or Below                       M
# ...       ...         ...                   ...                     ...
# 7065  LA72316  California              Bachelor                       M
# 7066  PK87824  California               College                       F
# 7067  TD14365  California              Bachelor                       M
# 7068  UP19263  California               College                       M
# 7069  Y167826  California               College                       M
#
#          policy type total claim amount
# 0      Personal Auto       Two-Door Car
# 1      Personal Auto       Two-Door Car
# 2      Personal Auto      Four-Door Car
# 3      Personal Auto                SUV
# 4      Personal Auto                SUV
# ...              ...                ...
# 7065   Personal Auto      Four-Door Car
# 7066  Corporate Auto      Four-Door Car
# 7067  Corporate Auto      Four-Door Car
# 7068   Personal Auto      Four-Door Car
# 7069  Corporate Auto       Two-Door Car
#
# [7070 rows x 6 columns]

# %% [markdown]
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
df1['customer lifetime value'] = df1['customer lifetime value'] * 100
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#                                 customer lifetime value   income  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# ...                                                 ...      ...
# 4003                                                NaN      NaN
# 4004                                                NaN      NaN
# 4005                                                NaN      NaN
# 4006                                                NaN      NaN
# 4007                                                NaN      NaN
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 4003                   NaN                       NaN             NaN
# 4004                   NaN                       NaN             NaN
# 4005                   NaN                       NaN             NaN
# 4006                   NaN                       NaN             NaN
# 4007                   NaN                       NaN             NaN
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 4003            NaN                 NaN
# 4004            NaN                 NaN
# 4005            NaN                 NaN
# 4006            NaN                 NaN
# 4007            NaN                 NaN
#
# [4008 rows x 11 columns]

# %%
df2['customer lifetime value'] = df2['customer lifetime value'] * 100
df2
# Out:
#     customer          st gender education  \
# 0    GS98873     Arizona      F  Bachelor
# 1    CW49887  California      F    Master
# 2    MY31220  California      F   College
# 3    UH35128      Oregon      F   College
# 4    WH52799     Arizona      F   College
# ..       ...         ...    ...       ...
# 991  HV85198     Arizona      M    Master
# 992  BS91566     Arizona      F   College
# 993  IL40123      Nevada      F   College
# 994  MY32149  California      F    Master
# 995  SA91515  California      M  Bachelor
#
#                                customer lifetime value  income  \
# 0    323912.47%323912.47%323912.47%323912.47%323912...   16061
# 1    462680.11%462680.11%462680.11%462680.11%462680...   79487
# 2    899704.02%899704.02%899704.02%899704.02%899704...   54230
# 3    2580706.30%2580706.30%2580706.30%2580706.30%25...   71210
# 4    380812.21%380812.21%380812.21%380812.21%380812...   94903
# ..                                                 ...     ...
# 991  847141.75%847141.75%847141.75%847141.75%847141...   63513
# 992  543121.91%543121.91%543121.91%543121.91%543121...   58161
# 993  568964.41%568964.41%568964.41%568964.41%568964...   83640
# 994  368672.38%368672.38%368672.38%368672.38%368672...       0
# 995  399258.39%399258.39%399258.39%399258.39%399258...       0
#
#      monthly premium auto number of open complaints  policy type  \
# 0                      88                    1/0/00   633.600000
# 1                     114                    1/0/00   547.200000
# 2                     112                    1/0/00   537.600000
# 3                     214                    1/1/00  1027.200000
# 4                      94                    1/0/00   451.200000
# ..                    ...                       ...          ...
# 991                    70                    1/0/00   185.667213
# 992                    68                    1/0/00   140.747286
# 993                    70                    1/0/00   471.050488
# 994                    96                    1/0/00    28.460568
# 995                   111                    1/0/00   700.349052
#
#       vehicle class total claim amount
# 0     Personal Auto      Four-Door Car
# 1      Special Auto                SUV
# 2     Personal Auto       Two-Door Car
# 3     Personal Auto         Luxury Car
# 4    Corporate Auto       Two-Door Car
# ..              ...                ...
# 991   Personal Auto      Four-Door Car
# 992  Corporate Auto      Four-Door Car
# 993  Corporate Auto       Two-Door Car
# 994   Personal Auto       Two-Door Car
# 995   Personal Auto                SUV
#
# [996 rows x 11 columns]

# %%
df3['customer lifetime value'] = df3['customer lifetime value'] * 100
df3
# Out:
#      customer          st        gender             education  \
# 0     SA25987  Washington   3479.137523  High School or Below
# 1     TB86706     Arizona   2502.637401                Master
# 2     ZL73902      Nevada   3265.156348              Bachelor
# 3     KX23516  California   4455.843406  High School or Below
# 4     FN77294  California   7704.958480  High School or Below
# ...       ...         ...           ...                   ...
# 7065  LA72316  California  23405.987980              Bachelor
# 7066  PK87824  California   3096.511217               College
# 7067  TD14365  California   8163.890428              Bachelor
# 7068  UP19263  California   7524.442436               College
# 7069  Y167826  California   2611.836866               College
#
#                                 customer lifetime value  income  \
# 0     MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...       0
# 1     MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...       0
# 2     FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...   25820
# 3     FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...       0
# 4     MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...   30366
# ...                                                 ...     ...
# 7065  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...   71941
# 7066  FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...   21604
# 7067  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...       0
# 7068  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...   21941
# 7069  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...       0
#
#       monthly premium auto  number of open complaints     policy type  \
# 0                      104                          0   Personal Auto
# 1                       66                          0   Personal Auto
# 2                       82                          0   Personal Auto
# 3                      121                          0   Personal Auto
# 4                      101                          2   Personal Auto
# ...                    ...                        ...             ...
# 7065                    73                          0   Personal Auto
# 7066                    79                          0  Corporate Auto
# 7067                    85                          3  Corporate Auto
# 7068                    96                          0   Personal Auto
# 7069                    77                          0  Corporate Auto
#
#       vehicle class total claim amount
# 0        499.200000       Two-Door Car
# 1          3.468912       Two-Door Car
# 2        393.600000      Four-Door Car
# 3        699.615192                SUV
# 4        484.800000                SUV
# ...             ...                ...
# 7065     198.234764      Four-Door Car
# 7066     379.200000      Four-Door Car
# 7067     790.784983      Four-Door Car
# 7068     691.200000      Four-Door Car
# 7069     369.600000       Two-Door Car
#
# [7070 rows x 11 columns]

# %% [markdown]
# and change dtype to numerical type.

# %%
df1['customer lifetime value'].dtype
# Out:
# dtype('O')

# %%
df2['customer lifetime value'].dtype
# Out:
# dtype('O')

# %%
df3['customer lifetime value'].dtype
# Out:
# dtype('O')
